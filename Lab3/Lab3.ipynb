# %%
 
import pandas as pd
from faker import Faker
from faker.providers.credit_card import Provider as CreditCardProvider 
import laundromat

# Display every row
pd.set_option('display.max_rows', None)

#Create a faker with norwegian
fake = Faker(['no_NO'])

#Initializing fake credential arrays
fake_names = []
fake_addresses = []
fake_personnrs = []
fake_credit_cards = []
fake_ipv4s = []

#100 fake credentials
for _ in range(100):
    # Creating fake credentials
    fake_name = fake.name()
    fake_address = fake.address()
    fake_personnr = fake.ssn()
    fake_credit_card = fake.credit_card_number()
    fake_ip = fake.ipv4()

    #Putting fake credentials
    fake_names.append(fake_name)
    fake_addresses.append(fake_address)
    fake_personnrs.append(fake_personnr)
    fake_credit_cards.append(fake_credit_card)
    fake_ipv4s.append(fake_ip)

df = pd.DataFrame({
    'Name' : fake_names, 
    'Address' : fake_addresses, 
    'PersonNr' : fake_personnrs, 
    'CreditCard' : fake_credit_cards, 
    'IPv4' : fake_ipv4s})
#Print dataframe
display(df)
# Out:
#                          Name                                Address  \
# 0            Ingrid Martinsen        Nielsenlia 77, 0182 Kirstenberg
# 1           Dr. Tor Ellingsen       Ahmedtoppen 463, 3035 Sigridfoss
# 2        Tom Iversen-Haugland       Ellingsenhøgda 92, 4172 Johansen
# 3           Cecilie Pettersen              Bergekra 4, 0197 Olavfoss
# 4          Håvard-Odd Ødegård     Amundsenstranda 4A, 7340 Helgehamn
# 5                Finn Evensen        Strømalléen 02C, 6830 Finngrunn
# 6         Erling-Geir Paulsen    Christensenstien 147, 5633 Jørgenås
# 7                Ruth Eriksen       Edvardsenberget 4C, 2979 Ødegård
# 8         Solveig-Hanna Bakke           Andreassenlia 9, 6775 Brekke
# 9        Rune-Daniel Pedersen      Kristensengjerdet 6E, 6501 Bakken
# 10            Christian Myhre             Halvorsenåsen 33, 1132 Ali
# 11      Prof. Sverre Haugland               Liesvingen 5F, 7498 Holm
# 12           Ellen-Maria Haug     Sivertsenrøa 96C, 6919 Sondresjøen
# ...

# %%
textArray = [] #Create a empty array
# Do a for loop, and assign values to name and adress
for _ in range(10):
    
    name = row[0] 
    adress = row[1]
    ssn = row[2]
    cc = row[3]
    #Using f string we can now create a new string with the values, and
    #append (add) that string to the text array
    textArray.append(f'Hi, my name is {name}. I wonder if you deliver to {adress}. My credi card nr is {cc} and my ssn is {ssn}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Thanh\OneDrive\Dokumenter\GitHub\DAVE3625\Lab3\Lab3.ipynb Cell 2 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Thanh/OneDrive/Dokumenter/GitHub/DAVE3625/Lab3/Lab3.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> # Do a for loop, and assign values to name and adress
#       <a href='vscode-notebook-cell:/c%3A/Users/Thanh/OneDrive/Dokumenter/GitHub/DAVE3625/Lab3/Lab3.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> for _ in range(10):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Thanh/OneDrive/Dokumenter/GitHub/DAVE3625/Lab3/Lab3.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a>     row =df.iloc[i]
#       <a href='vscode-notebook-cell:/c%3A/Users/Thanh/OneDrive/Dokumenter/GitHub/DAVE3625/Lab3/Lab3.ipynb#X34sZmlsZQ%3D%3D?line=4'>5</a>     name = row[0]
# ...
